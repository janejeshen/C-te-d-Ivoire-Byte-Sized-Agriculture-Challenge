# %%
# !pip install rasterio -q

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os
import rasterio
from tqdm.notebook import tqdm
import shap

# Set random seed for reproducibility
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ### Data Loading and Exploration

# %%
DATA_PATH = r'C:\Users\janen\Desktop\byte sized'

train_dataset = pd.read_csv(os.path.join(DATA_PATH, 'TrainDataset.csv'))
test_dataset = pd.read_csv(os.path.join(DATA_PATH, 'TestDataset.csv'))

train_images_path = os.path.join(DATA_PATH, 'S2Images/train')
test_images_path = os.path.join(DATA_PATH, 'S2Images/test')

# %%
# Lets drop null tifpaths
train_dataset = train_dataset.dropna(subset=['tifPath'])
test_dataset = test_dataset.dropna(subset=['tifPath'])

print(f"Train dataset shape: {train_dataset.shape}")
print(f"Test dataset shape: {test_dataset.shape}")
# Out:
# Train dataset shape: (7433, 6)
# Test dataset shape: (2201, 4)

# %%
# Replace the image paths
train_dataset['tifPath'] = train_dataset['tifPath'].apply(lambda x: os.path.join(train_images_path, os.path.basename(x)))
test_dataset['tifPath'] = test_dataset['tifPath'].apply(lambda x: os.path.join(test_images_path, os.path.basename(x)))

# View train data
train_dataset.head()
# Out:
#               ID  year month  \
# 0  ID_h14T0B_Jan  2024   Jan
# 1  ID_KbyKOr_Jan  2024   Jan
# 2  ID_t4Tmmn_Jan  2024   Jan
# 3  ID_yipWoC_Jan  2024   Jan
# 4  ID_XKiksa_Jan  2024   Jan
#
#                                              tifPath  Target  class
# 0  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 1  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 2  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 3  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 4  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3

# %%
# View test data
test_dataset.head()
# Out:
#               ID  year month  \
# 0  ID_731818_Jan  2024   Jan
# 1  ID_790093_Jan  2024   Jan
# 2  ID_931033_Jan  2024   Jan
# 3  ID_079024_Jan  2024   Jan
# 4  ID_691532_Jan  2024   Jan
#
#                                              tifPath
# 0  C:\Users\janen\Desktop\byte sized\S2Images/tes...
# 1  C:\Users\janen\Desktop\byte sized\S2Images/tes...
# 2  C:\Users\janen\Desktop\byte sized\S2Images/tes...
# 3  C:\Users\janen\Desktop\byte sized\S2Images/tes...
# 4  C:\Users\janen\Desktop\byte sized\S2Images/tes...

# %% [markdown]
# ### Data Preprocessing

# %%
print(f"Train dataset shape: {train_dataset.shape}")
print(f"Test dataset shape: {test_dataset.shape}")
# Out:
# Train dataset shape: (7433, 6)
# Test dataset shape: (2201, 4)

# %%
train_dataset.head()
# Out:
#               ID  year month  \
# 0  ID_h14T0B_Jan  2024   Jan
# 1  ID_KbyKOr_Jan  2024   Jan
# 2  ID_t4Tmmn_Jan  2024   Jan
# 3  ID_yipWoC_Jan  2024   Jan
# 4  ID_XKiksa_Jan  2024   Jan
#
#                                              tifPath  Target  class
# 0  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 1  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 2  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 3  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3
# 4  C:\Users\janen\Desktop\byte sized\S2Images/tra...  Rubber      3

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from functools import partial


def process_single_file(row, all_bands, is_train=False):

    tif_path = row["tifPath"]
    if pd.isna(tif_path) or not os.path.exists(tif_path):
        print(f"Missing or invalid path: {tif_path}")
        return None

    try:
        with rasterio.open(tif_path) as src:
            band_means = {}
            for i in range(1, src.count + 1):
                if i-1 < len(all_bands):
                    band_name = all_bands[i - 1]
                    band_data = src.read(i).astype('float32')
                    band_data[band_data == 0] = np.nan
                    mean_val = np.nanmean(band_data)
                    band_means[f"{band_name}"] = mean_val

        row_data = {
            "ID": row["ID"],
            "month": row["month"] if "month" in row else None,
            **band_means
        }

        if is_train:
            if "Target" in row:
                row_data["Crop"] = row["Target"]
            if "class" in row:
                row_data["class"] = row["class"]

        return row_data

    except Exception as e:
        print(f"Error processing {tif_path}: {e}")
        return None

def extract_sentinel2_features(df: pd.DataFrame, data_path: str, output_filename: str, is_train: bool = False, workers: int = 4) -> pd.DataFrame:

    ALL_BANDS = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12']

    # Create a partial function with fixed parameters
    process_func = partial(process_single_file, all_bands=ALL_BANDS, is_train=is_train)

    features = []

    print(f"Processing {len(df)} files using {workers} parallel workers...")

    with ThreadPoolExecutor(max_workers=workers) as executor:

        future_to_row = {executor.submit(process_func, row): idx for idx, row in df.iterrows()}

        for future in tqdm(as_completed(future_to_row), total=len(future_to_row), desc="Extracting Sentinel-2 features"):
            result = future.result()
            if result:
                features.append(result)

    features_df = pd.DataFrame(features)

    # Calculate success rate
    success_rate = len(features_df) / len(df) * 100
    print(f"Successfully processed {len(features_df)} out of {len(df)} files ({success_rate:.1f}%)")

    # Save to CSV
    os.makedirs(data_path, exist_ok=True)
    output_path = os.path.join(data_path, output_filename)
    features_df.to_csv(output_path, index=False)
    print(f"Saved features to {output_path}")

    return features_df

# Lets save the features in the drive
# drive_path = '/content/drive/MyDrive/Zindi/Computer-Vision/Byte-Sized-Agriculture-Challenge'
train_features_path = os.path.join(DATA_PATH, 'train_features.csv')
test_features_path = os.path.join(DATA_PATH, 'test_features.csv')

train_features_df = extract_sentinel2_features(
        train_dataset,
        data_path=train_images_path,
        output_filename=train_features_path,
        is_train=True,
        workers=4
    )

test_features_df = extract_sentinel2_features(
        test_dataset,
        data_path=test_images_path,
        output_filename=test_features_path,
        is_train=False,
        workers=4
    )
# Out:
# Processing 7433 files using 4 parallel workers...
# Extracting Sentinel-2 features:   0%|          | 0/7433 [00:00<?, ?it/s]
# Successfully processed 7433 out of 7433 files (100.0%)
# Saved features to C:\Users\janen\Desktop\byte sized\train_features.csv
# Processing 2201 files using 4 parallel workers...
# Extracting Sentinel-2 features:   0%|          | 0/2201 [00:00<?, ?it/s]
# Successfully processed 2201 out of 2201 files (100.0%)
# Saved features to C:\Users\janen\Desktop\byte sized\test_features.csv

# %%
train_features_df = pd.read_csv(train_features_path)
test_features_df = pd.read_csv(test_features_path)

# %%
# Lets reshuffle the data to ensure the model sees a balanced mix of classes and features during training.
# This is important before splitting into training and validation sets, or when using k-fold cross-validation.
# train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
# train_df.head()

# %%
train_features_df.head()
# Out:
#               ID month         B1         B2         B3         B4         B5  \
# 0  ID_XKiksa_Jan   Jan  2682.8823  2397.5918  2242.9766  2029.4625  2213.2996
# 1  ID_zNx6qQ_Jan   Jan  2474.2490  2178.7156  2017.1100  1758.7551  1991.0884
# 2  ID_KfCbOO_Jan   Jan  4412.2400  4380.4610  4334.2925  4563.7040  4494.2993
# 3  ID_t4Tmmn_Jan   Jan  2530.2866  2249.9440  2119.3372  1885.4717  2182.2764
# 4  ID_yipWoC_Jan   Jan  2559.1108  2277.1003  2145.3406  1892.4064  2193.6190
#
#           B6         B7         B8        B8A         B9        B11  \
# 0  3100.5940  3519.4102  3330.7097  3770.8628  1361.7290  2671.8386
# 1  3102.2307  3639.9497  3476.3760  3977.7048  1369.7843  2658.6950
# 2  5044.0100  5500.9053  5142.3920  5801.8687  1679.6248  5167.2896
# 3  3226.1155  3708.2402  3550.9780  4069.9988  1433.3107  2978.0210
# 4  3258.0647  3764.3198  3599.2930  4158.3516  1409.1418  2981.6630
#
#          B12    Crop  class
# 0  1892.7155  Rubber      3
# 1  1704.2468  Rubber      3
# 2  4236.1760    Palm      2
# 3  1940.8265  Rubber      3
# 4  1906.5609  Rubber      3

# %% [markdown]
# ### Feature Engineering

# %%
print(f"Train dataset shape: {train_features_df.shape}")
print(f"Test dataset shape: {test_features_df.shape}")
# Out:
# Train dataset shape: (7433, 16)
# Test dataset shape: (2201, 14)

# %%
# Extract base IDs (without month)
train_features_df['base_id'] = train_features_df['ID'].str.split('_').str[1]
test_features_df['base_id'] = test_features_df['ID'].str.split('_').str[1]

# Create submission ID format (ID_XXXXX)
train_features_df['submission_id'] = 'ID_' + train_features_df['base_id']
test_features_df['submission_id'] = 'ID_' + test_features_df['base_id']

print(f"Number of unique IDs in test data: {test_features_df['base_id'].nunique()}")

# Encode target labels
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_features_df['Crop_encoded'] = label_encoder.fit_transform(train_features_df['Crop'])
print("\nEncoded labels:")
for i, label in enumerate(label_encoder.classes_):
    print(f"{label}: {i}")
# Out:
# Number of unique IDs in test data: 282
#
# Encoded labels:
# Cocoa: 0
# Palm: 1
# Rubber: 2

# %%
# Convert the month column to numerical values
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
train_features_df['month_num'] = train_features_df['month'].map(month_mapping)
test_features_df['month_num'] = test_features_df['month'].map(month_mapping)

# %%
# Enhanced Feature Engineering
def create_enhanced_features(df):
    """Create advanced features from the spectral bands"""

    # -------- Basic Vegetation Indices --------
    # NDVI (Normalized Difference Vegetation Index)
    df['NDVI'] = (df['B8'] - df['B4']) / (df['B8'] + df['B4'])

    # EVI (Enhanced Vegetation Index)
    df['EVI'] = 2.5 * ((df['B8'] - df['B4']) / (df['B8'] + 6 * df['B4'] - 7.5 * df['B2'] + 1))

    # SAVI (Soil Adjusted Vegetation Index)
    L = 0.5  # soil brightness correction factor
    df['SAVI'] = ((df['B8'] - df['B4']) / (df['B8'] + df['B4'] + L)) * (1 + L)

    # NDWI (Normalized Difference Water Index)
    df['NDWI'] = (df['B3'] - df['B8']) / (df['B3'] + df['B8'])

    # NDBI (Normalized Difference Built-up Index)
    df['NDBI'] = (df['B11'] - df['B8']) / (df['B11'] + df['B8'])

    # NBR (Normalized Burn Ratio)
    df['NBR'] = (df['B8'] - df['B12']) / (df['B8'] + df['B12'])

    # NDRE (Normalized Difference Red Edge)
    df['NDRE'] = (df['B8'] - df['B5']) / (df['B8'] + df['B5'])

    # ------------ Additional Advanced Indices ----------------------

    # MTCI (MERIS Terrestrial Chlorophyll Index) - sensitive to chlorophyll content
    df['MTCI'] = (df['B8'] - df['B5']) / (df['B5'] - df['B4'])

    # MCARI (Modified Chlorophyll Absorption Ratio Index)
    df['MCARI'] = ((df['B5'] - df['B4']) - 0.2 * (df['B5'] - df['B3'])) * (df['B5'] / df['B4'])

    # GNDVI (Green Normalized Difference Vegetation Index)
    df['GNDVI'] = (df['B8'] - df['B3']) / (df['B8'] + df['B3'])

    # PSRI (Plant Senescence Reflectance Index) - good for identifying crop maturity
    df['PSRI'] = (df['B4'] - df['B3']) / df['B8']

    # SIPI (Structure Insensitive Pigment Index)
    df['SIPI'] = (df['B8'] - df['B2']) / (df['B8'] - df['B4'])

    # ARVI (Atmospherically Resistant Vegetation Index)
    df['ARVI'] = (df['B8'] - (2 * df['B4'] - df['B2'])) / (df['B8'] + (2 * df['B4'] - df['B2']))

    # MSI (Moisture Stress Index)
    df['MSI'] = df['B11'] / df['B8']

    # NDMI (Normalized Difference Moisture Index)
    df['NDMI'] = (df['B8'] - df['B11']) / (df['B8'] + df['B11'])

    # CIrededge (Chlorophyll Index Red-Edge)
    df['CIrededge'] = (df['B8'] / df['B5']) - 1

    # CIgreen (Chlorophyll Index Green)
    df['CIgreen'] = (df['B8'] / df['B3']) - 1

    # Band ratios and combinations
    df['B8_B4'] = df['B8'] / df['B4']
    df['B11_B8'] = df['B11'] / df['B8']
    df['B2_B3'] = df['B2'] / df['B3']
    df['B4_B3'] = df['B4'] / df['B3']
    df['B5_B4'] = df['B5'] / df['B4']
    df['B6_B5'] = df['B6'] / df['B5']
    df['B7_B6'] = df['B7'] / df['B6']
    df['B8A_B8'] = df['B8A'] / df['B8']
    df['B11_B12'] = df['B11'] / df['B12']

    # ------- Texture-related features (simple approximations) --------
    # Variance in visible spectrum
    df['var_vis'] = df[['B2', 'B3', 'B4']].var(axis=1)

    # Variance in NIR
    df['var_nir'] = df[['B8', 'B8A']].var(axis=1)

    # Variance in SWIR
    df['var_swir'] = df[['B11', 'B12']].var(axis=1)

    # Statistical features
    df['mean_vis'] = df[['B2', 'B3', 'B4']].mean(axis=1)
    df['mean_nir'] = df[['B8', 'B8A']].mean(axis=1)
    df['mean_swir'] = df[['B11', 'B12']].mean(axis=1)
    df['mean_rededge'] = df[['B5', 'B6', 'B7']].mean(axis=1)

    df['min_vis'] = df[['B2', 'B3', 'B4']].min(axis=1)
    df['min_nir'] = df[['B8', 'B8A']].min(axis=1)
    df['min_swir'] = df[['B11', 'B12']].min(axis=1)
    df['min_rededge'] = df[['B5', 'B6', 'B7']].min(axis=1)

    df['max_vis'] = df[['B2', 'B3', 'B4']].max(axis=1)
    df['max_nir'] = df[['B8', 'B8A']].max(axis=1)
    df['max_swir'] = df[['B11', 'B12']].max(axis=1)
    df['max_rededge'] = df[['B5', 'B6', 'B7']].max(axis=1)

    df['range_vis'] = df['max_vis'] - df['min_vis']
    df['range_nir'] = df['max_nir'] - df['min_nir']
    df['range_swir'] = df['max_swir'] - df['min_swir']
    df['range_rededge'] = df['max_rededge'] - df['min_rededge']

    # Seasonal features - sine and cosine transformations
    df['month_sin'] = np.sin(2 * np.pi * df['month_num'] / 12)
    df['month_cos'] = np.cos(2 * np.pi * df['month_num'] / 12)

    # Season categorical (1=Winter, 2=Spring, 3=Summer, 4=Fall)
    df['season'] = ((df['month_num'] % 12 + 3) // 3) % 4 + 1

    # Growth phase approximation (based on month in tropical regions)
    # This is a simplified approximation and we could be refine it later with actual crop calendars
    # For West Africa: roughly planting in April-May, growing in June-Sept, harvesting in Oct-Dec
    conditions = [
        (df['month_num'].isin([4, 5])),  # Planting
        (df['month_num'].isin([6, 7, 8, 9])),  # Growing
        (df['month_num'].isin([10, 11, 12])),  # Harvesting
        (df['month_num'].isin([1, 2, 3]))  # Post-harvest/fallow
    ]
    choices = [1, 2, 3, 4]
    df['growth_phase'] = np.select(conditions, choices, default=0)

    return df

train_features_df = create_enhanced_features(train_features_df)
test_features_df = create_enhanced_features(test_features_df)

# %%
def safe_div(a, b):
    return a / (b + 1e-6)

def engineer_features(df):
    # --- 1. Spectral Index Ratios & Differences ---
    df['EVI_NDVI_ratio'] = safe_div(df['EVI'], df['NDVI'])
    df['NDWI_NDVI_diff'] = df['NDWI'] - df['NDVI']
    df['NBR_NDMI_ratio'] = safe_div(df['NBR'], df['NDMI'])
    df['MCARI_MTCI'] = safe_div(df['MCARI'], df['MTCI'])

    # --- 2. Band Combinations ---
    df['B8_B5_ratio'] = safe_div(df['B8'], df['B5'])
    df['B4_B2_ratio'] = safe_div(df['B4'], df['B2'])
    df['B11_B4_ratio'] = safe_div(df['B11'], df['B4'])

    df['B5_minus_B4'] = df['B5'] - df['B4']
    df['B6_minus_B2'] = df['B6'] - df['B2']

    df['avg_rededge'] = (df['B5'] + df['B6'] + df['B7']) / 3
    df['avg_swir'] = (df['B11'] + df['B12']) / 2

    # --- 3. Statistical Features ---
    df['vis_nir_contrast'] = abs(df['mean_vis'] - df['mean_nir'])
    df['swir_vis_ratio'] = safe_div(df['mean_swir'], df['mean_vis'])
    df['total_range'] = df['range_vis'] + df['range_nir'] + df['range_swir'] + df['range_rededge']
    df['mean_all'] = (df['mean_vis'] + df['mean_nir'] + df['mean_swir'] + df['mean_rededge']) / 4

    # --- 4. Vegetation Health and Stress ---
    df['vegetation_health_index'] = (df['NDVI'] + df['EVI'] + df['SAVI']) / 3
    df['water_stress_index'] = df['NDWI'] - df['MSI']
    df['chlorophyll_index'] = (df['CIrededge'] + df['CIgreen']) / 2

    # --- 5. Temporal/Categorical Features ---
    df['month_quarter'] = pd.to_datetime(df['month'], format='%B', errors='coerce').dt.quarter
    df['is_growing_season'] = df['month_num'].apply(lambda x: 1 if x in [3, 4, 5, 6, 7, 8] else 0)

    # --- 6. Additional Advanced Features ---
    df['B2_B4_ratio'] = safe_div(df['B2'], df['B4'])
    df['B3_B5_ratio'] = safe_div(df['B3'], df['B5'])
    df['B8_B11_ratio'] = safe_div(df['B8'], df['B11'])
    df['B12_B8A_ratio'] = safe_div(df['B12'], df['B8A'])

    df['NDVI_SAVI_avg'] = (df['NDVI'] + df['SAVI']) / 2
    df['EVI_SAVI_ratio'] = safe_div(df['EVI'], df['SAVI'])
    df['NDRE_GNDVI_ratio'] = safe_div(df['NDRE'], df['GNDVI'])

    df['B8_NDVI_product'] = df['B8'] * df['NDVI']
    df['B11_NDWI_product'] = df['B11'] * df['NDWI']

    df['min_all'] = (df['min_vis'] + df['min_nir'] + df['min_swir'] + df['min_rededge']) / 4
    df['max_all'] = (df['max_vis'] + df['max_nir'] + df['max_swir'] + df['max_rededge']) / 4

    df['norm_range_vis'] = safe_div(df['range_vis'], df['max_vis'])
    df['norm_range_nir'] = safe_div(df['range_nir'], df['max_nir'])

    df['red_rededge_diff'] = df['mean_rededge'] - df['mean_vis']

    df['var_vis_nir_ratio'] = safe_div(df['var_vis'], df['var_nir'])
    df['var_swir_nir_ratio'] = safe_div(df['var_swir'], df['var_nir'])

    df['entropy_vis'] = safe_div(df['range_vis'], df['mean_vis'])
    df['entropy_nir'] = safe_div(df['range_nir'], df['mean_nir'])

    df['avg_veg_index'] = (df['NDVI'] + df['EVI'] + df['SAVI'] + df['GNDVI']) / 4
    df['avg_stress_index'] = (df['MSI'] + df['NDMI'] + df['PSRI']) / 3
    df['color_ratio_avg'] = (df['SIPI'] + df['ARVI']) / 2

    df['NDVI_squared'] = df['NDVI'] ** 2
    df['EVI_squared'] = df['EVI'] ** 2
    df['NDWI_squared'] = df['NDWI'] ** 2

    df['NDVI_EVI_product'] = df['NDVI'] * df['EVI']
    df['SAVI_NDWI_product'] = df['SAVI'] * df['NDWI']

    return df


train_features_df = engineer_features(train_features_df)
test_features_df = engineer_features(test_features_df)

# %%
# Handle potential NaN values from division operations
train_features_df = train_features_df.replace([np.inf, -np.inf], np.nan)
test_features_df = test_features_df.replace([np.inf, -np.inf], np.nan)
train_features_df = train_features_df.fillna(0)
test_features_df = test_features_df.fillna(0)

# %%
train_features_df.head()
# Out:
#               ID month         B1         B2         B3         B4         B5  \
# 0  ID_XKiksa_Jan   Jan  2682.8823  2397.5918  2242.9766  2029.4625  2213.2996
# 1  ID_zNx6qQ_Jan   Jan  2474.2490  2178.7156  2017.1100  1758.7551  1991.0884
# 2  ID_KfCbOO_Jan   Jan  4412.2400  4380.4610  4334.2925  4563.7040  4494.2993
# 3  ID_t4Tmmn_Jan   Jan  2530.2866  2249.9440  2119.3372  1885.4717  2182.2764
# 4  ID_yipWoC_Jan   Jan  2559.1108  2277.1003  2145.3406  1892.4064  2193.6190
#
#           B6         B7         B8  ...  entropy_vis  entropy_nir  \
# 0  3100.5940  3519.4102  3330.7097  ...     0.165575     0.123959
# 1  3102.2307  3639.9497  3476.3760  ...     0.211582     0.134511
# 2  5044.0100  5500.9053  5142.3920  ...     0.051831     0.120516
# 3  3226.1155  3708.2402  3550.9780  ...     0.174814     0.136208
# 4  3258.0647  3764.3198  3599.2930  ...     0.182757     0.144131
#
#    avg_veg_index  avg_stress_index color_ratio_avg  NDVI_squared EVI_squared  \
# 0      -0.128297          0.282615        0.525751      0.058933    1.729785
# 1      -0.193175          0.274584        0.599713      0.107646    3.454121
# 2      -1.044636          0.349013        0.678320      0.003555   19.473370
# 3      -0.263356          0.286848        0.590699      0.093856    4.292191
# 4      -0.244854          0.283993        0.592087      0.096604    4.038093
#
#   NDWI_squared  NDVI_EVI_product  SAVI_NDWI_product
# 0     0.038085         -0.319284          -0.071058
# 1     0.070562         -0.609774          -0.130718
# 2     0.007271         -0.263100          -0.007626
# 3     0.063746         -0.634703          -0.116014
# 4     0.064058         -0.624577          -0.117988
#
# [5 rows x 115 columns]

# %%
train_features_df.columns
# Out:
# Index(['ID', 'month', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8',
#        ...
#        'entropy_vis', 'entropy_nir', 'avg_veg_index', 'avg_stress_index',
#        'color_ratio_avg', 'NDVI_squared', 'EVI_squared', 'NDWI_squared',
#        'NDVI_EVI_product', 'SAVI_NDWI_product'],
#       dtype='object', length=115)

# %%
# Check for null values
train_features_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Modelling

# %%
# print cols  in train df and not in test_df

train_cols = set(train_features_df.columns)
test_cols = set(test_features_df.columns)

cols_in_train_not_in_test = train_cols - test_cols
cols_in_train_not_in_test
# Out:
# {'Crop', 'Crop_encoded', 'class'}

# %%
train_features_df[['Crop', 'Crop_encoded', 'class']]
# Out:
#         Crop  Crop_encoded  class
# 0     Rubber             2      3
# 1     Rubber             2      3
# 2       Palm             1      2
# 3     Rubber             2      3
# 4     Rubber             2      3
# ...      ...           ...    ...
# 7428   Cocoa             0      1
# 7429   Cocoa             0      1
# 7430   Cocoa             0      1
# 7431   Cocoa             0      1
# 7432   Cocoa             0      1
#
# [7433 rows x 3 columns]

# %%
# Check for label distribution
y = train_features_df['Crop_encoded']
y.value_counts()
# Out:
# Crop_encoded
# 2    3068
# 1    2477
# 0    1888
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Features and labels
feature_cols = [col for col in train_features_df.columns if col not in ['ID', 'month', 'Crop', 'Crop_encoded', 'class', 'base_id', 'submission_id']]
print(f"\nNumber of features: {len(feature_cols)}")

X = train_features_df[feature_cols]
y = train_features_df['Crop_encoded']

# Train/test split
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val_scaled, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=SEED)

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_scaled, y_train = smote.fit_resample(X_train, y_train)

# from imblearn.combine import SMOTETomek

# smt = SMOTETomek(random_state=42)
# X_train_scaled, y_train = smt.fit_resample(X_train, y_train)


# # Scale features
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_val_scaled = scaler.transform(X_val)
# X_test_scaled = scaler.transform(test_features_df[feature_cols])
# Out:
# Number of features: 108

# %%
import lightgbm as lgb

lgb_params =  {'objective': 'multiclass', 'num_class': len(label_encoder.classes_), 'metric': 'multi_logloss', 
               'boosting_type': 'gbdt', 'num_leaves': 97, 'learning_rate': 0.025679514558557614,
                 'feature_fraction': 0.8734246008310188, 'bagging_fraction': 0.9735558007196473, 
                 'bagging_freq': 9, 'max_depth': 19, 'min_child_samples': 12, 'verbose': -1, 'random_state': 42}


# Create LightGBM dataset objects
train_data = lgb.Dataset(X_train_scaled, label=y_train)
val_data = lgb.Dataset(X_val_scaled, label=y_val, reference=train_data)

# Train the model
print("Training LightGBM model...")
model = lgb.train(
    lgb_params,
    train_data,
    num_boost_round=500,
    valid_sets=[train_data, val_data],
    valid_names=['train', 'valid'],
    callbacks=[
        lgb.early_stopping(stopping_rounds=50),
        lgb.log_evaluation(period=100)
    ]
)
# Out:
# Training LightGBM model...
# Training until validation scores don't improve for 50 rounds
# [100]	train's multi_logloss: 0.184025	valid's multi_logloss: 0.436441
# [200]	train's multi_logloss: 0.0610297	valid's multi_logloss: 0.391157
# Early stopping, best iteration is:
# [225]	train's multi_logloss: 0.0477538	valid's multi_logloss: 0.390098

# %%
# Evaluate the model
from sklearn.metrics import f1_score

y_pred = np.argmax(model.predict(X_val_scaled), axis=1)
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\nValidation F1 Score (macro): {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_val, y_pred))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_val, y_pred)
class_names = ['Cocoa', 'Palm', 'Rubber']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Validation F1 Score (macro): 0.8462
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92       387
#            1       0.77      0.81      0.79       492
#            2       0.83      0.82      0.82       608
#
#     accuracy                           0.84      1487
#    macro avg       0.85      0.84      0.85      1487
# weighted avg       0.84      0.84      0.84      1487

# %%
# Feature importance
feature_cols = X_train.columns
plt.figure(figsize=(14, 10))
feature_importance = pd.DataFrame({
    'Feature': feature_cols,
    'Importance': model.feature_importance()
})
feature_importance = feature_importance.sort_values('Importance', ascending=False)
top_features = feature_importance.head(25)
sns.barplot(x='Importance', y='Feature', data=top_features)
plt.title('Top 25 Feature Importances')
plt.tight_layout()
plt.show()

# %%
# Create SHAP explainer
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)

# Plot SHAP feature importance
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Create SHAP explainer
explainer = shap.TreeExplainer(model)  # Your trained LightGBM model
shap_values = explainer.shap_values(X_train_scaled)

# Calculate mean absolute SHAP values for each feature across all classes
if isinstance(shap_values, list):  # For multiclass
    shap_importance = np.abs(np.array(shap_values)).mean(axis=0).mean(axis=0)
else:  # For binary classification
    shap_importance = np.abs(shap_values).mean(axis=0)

# Get top 20 feature indices
top_20_indices = np.argsort(shap_importance)[-20:][::-1]

# %%
X_train_top20 = X_train_scaled[:, top_20_indices]
X_val_top20 = X_val_scaled[:, top_20_indices]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([[0, 2, 1],
#        [1, 0, 2],
#        [0, 2, 1],
#        [1, 0, 2],
#        [0, 2, 1],
#        [0, 2, 1],
#        [2, 0, 1],
#        [1, 0, 2],
#        [1, 0, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [2, 0, 1],
#        [0, 2, 1],
#        [2, 1, 0],
#        [0, 1, 2],
#        [2, 1, 0],
#        [2, 1, 0],
#        [1, 0, 2],
#        [0, 2, 1],
#        [0, 1, 2]]))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 X_train_top20 = X_train_scaled[:, top_20_indices]
#       2 X_val_top20 = X_val_scaled[:, top_20_indices]
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:3817, in Index.get_loc(self, key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:6059, in Index._check_indexing_error(self, key)
#    6055 def _check_indexing_error(self, key):
#    6056     if not is_scalar(key):
#    6057         # if key is not a scalar, directly raise an error (the code below
#    6058         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), array([[0, 2, 1],
#        [1, 0, 2],
#        [0, 2, 1],
#        [1, 0, 2],
#        [0, 2, 1],
#        [0, 2, 1],
#        [2, 0, 1],
#        [1, 0, 2],
#        [1, 0, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [2, 0, 1],
#        [0, 2, 1],
#        [2, 1, 0],
#        [0, 1, 2],
#        [2, 1, 0],
#        [2, 1, 0],
#        [1, 0, 2],
#        [0, 2, 1],
#        [0, 1, 2]]))

# %%
# Create new datasets with top 20 features
train_data_top20 = lgb.Dataset(X_train_top20, label=y_train)
val_data_top20 = lgb.Dataset(X_val_top20, label=y_val, reference=train_data_top20)

# Train new model
model_top20 = lgb.train(
    lgb_params,
    train_data_top20,
    num_boost_round=500,
    valid_sets=[train_data_top20, val_data_top20],
    valid_names=['train', 'valid'],
    callbacks=[
        lgb.early_stopping(stopping_rounds=50),
        lgb.log_evaluation(period=100)
    ]
)

# %%
# Evaluate the model
from sklearn.metrics import f1_score

y_pred = np.argmax(model_top20.predict(X_val_scaled), axis=1)
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\nValidation F1 Score (macro): {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_val, y_pred))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_val, y_pred)
class_names = ['Cocoa', 'Palm', 'Rubber']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
sns.countplot(x='Crop_encoded', data=train_features_df)
plt.title("Class Distribution")
plt.show()

# %%
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define model
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.05,
    depth=8,
    loss_function='MultiClass',
    eval_metric='MultiClass',
    random_seed=SEED,
    verbose=100,
    early_stopping_rounds=50
)

# Create Pool objects for CatBoost
train_pool = Pool(data=X_train_scaled, label=y_train)
val_pool = Pool(data=X_val_scaled, label=y_val)

# Train the model
print("Training CatBoost model...")
catboost_model.fit(train_pool, eval_set=val_pool)

# Predict
y_pred_probs = catboost_model.predict_proba(X_val_scaled)
y_pred = np.argmax(y_pred_probs, axis=1)

# Evaluate with F1 Score
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\nValidation F1 Score (macro): {f1:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=['Cocoa', 'Palm', 'Rubber']))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_val, y_pred)
class_names = ['Cocoa', 'Palm', 'Rubber']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Training CatBoost model...
# 0:	learn: 1.0676096	test: 1.0712868	best: 1.0712868 (0)	total: 199ms	remaining: 1m 39s
# 100:	learn: 0.4746252	test: 0.5642591	best: 0.5642591 (100)	total: 22.3s	remaining: 1m 28s
# 200:	learn: 0.3694211	test: 0.4947588	best: 0.4947588 (200)	total: 45.1s	remaining: 1m 7s
# 300:	learn: 0.2993543	test: 0.4523445	best: 0.4523445 (300)	total: 1m 7s	remaining: 44.8s
# 400:	learn: 0.2547641	test: 0.4293204	best: 0.4293204 (400)	total: 1m 29s	remaining: 22.1s
# 499:	learn: 0.2199524	test: 0.4136699	best: 0.4136699 (499)	total: 1m 50s	remaining: 0us
#
# bestTest = 0.4136698839
# bestIteration = 499
#
#
# Validation F1 Score (macro): 0.8406
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Cocoa       0.96      0.89      0.92       387
#         Palm       0.76      0.81      0.78       492
#       Rubber       0.82      0.81      0.82       608
#
#     accuracy                           0.83      1487
#    macro avg       0.85      0.84      0.84      1487
# weighted avg       0.84      0.83      0.83      1487

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# 1. Get top 20 features from SHAP (as before)
explainer = shap.TreeExplainer(model)  # Your trained LightGBM model
shap_values = explainer.shap_values(X_train_scaled)
shap_importance = np.abs(np.array(shap_values)).mean(axis=0).mean(axis=0)
top_20_indices = np.argsort(shap_importance)[-20:][::-1]

# 2. Filter datasets
X_train_top20 = X_train[:, top_20_indices]
X_val_top20 = X_val_scaled[:, top_20_indices]

# 3. Random Forest parameters (optimized for F1-score)
rf_params = {
    'n_estimators': 500,
    'criterion': 'gini',  # 'entropy' sometimes works better for imbalanced classes
    'max_depth': 19,
    'min_samples_leaf': 12,
    'max_features': 0.873,  # Matches your LightGBM feature_fraction
    'class_weight': 'balanced',  # Important for F1-score with imbalanced classes
    'random_state': 42,
    'n_jobs': -1
}

# 4. Train model
print("Training Random Forest on top 20 features...")
rf_model = RandomForestClassifier(**rf_params)
rf_model.fit(X_train_top20, y_train)

# 5. Evaluate using macro F1-score
y_train_pred = rf_model.predict(X_train_top20)
y_val_pred = rf_model.predict(X_val_top20)

train_f1 = f1_score(y_train, y_train_pred, average='macro')
val_f1 = f1_score(y_val, y_val_pred, average='macro')

print(f"\nTraining Macro F1-score: {train_f1:.4f}")
print(f"Validation Macro F1-score: {val_f1:.4f}")

# Feature names tracking (if available)
if hasattr(X_train_scaled, 'columns'):
    print("\nTop 20 features used:")
    print(X_train_scaled.columns[top_20_indices].tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([0, 2, 1]))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[36], line 11
#       8 top_20_indices = np.argsort(shap_importance)[-20:][::-1]
#      10 # 2. Filter datasets
# ---> 11 X_train_top20 = X_train[:, top_20_indices]
#      12 X_val_top20 = X_val_scaled[:, top_20_indices]
#      14 # 3. Random Forest parameters (optimized for F1-score)
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:3817, in Index.get_loc(self, key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\pandas\core\indexes\base.py:6059, in Index._check_indexing_error(self, key)
#    6055 def _check_indexing_error(self, key):
#    6056     if not is_scalar(key):
#    6057         # if key is not a scalar, directly raise an error (the code below
#    6058         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), array([0, 2, 1]))

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

gb_params = {'n_estimators': 333, 'learning_rate': 0.29728232981278574, 'max_depth': 9, 
'min_samples_split': 8,'min_samples_leaf': 5, 'subsample': 0.5822537141129174, 'max_features': None}

# # Define model
# gb_model = GradientBoostingClassifier(
#     n_estimators=500,
#     learning_rate=0.05,
#     max_depth=8,
#     subsample=0.8,
#     random_state=SEED
# )
# Define model
gb_model = GradientBoostingClassifier(random_state=42, **gb_params)

# Train model
print("Training Gradient Boosting model...")
gb_model.fit(X_train_scaled, y_train)

# Predict
y_pred = gb_model.predict(X_val_scaled)

# Evaluate
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\nValidation F1 Score (macro): {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=['Cocoa', 'Palm', 'Rubber']))

# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_val, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Cocoa', 'Palm', 'Rubber'],
            yticklabels=['Cocoa', 'Palm', 'Rubber'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Gradient Boosting Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Training Gradient Boosting model...
#
# Validation F1 Score (macro): 0.8497
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Cocoa       0.95      0.91      0.93       387
#         Palm       0.78      0.81      0.79       492
#       Rubber       0.83      0.82      0.83       608
#
#     accuracy                           0.84      1487
#    macro avg       0.85      0.85      0.85      1487
# weighted avg       0.84      0.84      0.84      1487

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score
import optuna

def objective_gb(trial):
    model = GradientBoostingClassifier(
        n_estimators=trial.suggest_int('n_estimators', 100, 800),
        learning_rate=trial.suggest_float('learning_rate', 0.01, 0.3),
        max_depth=trial.suggest_int('max_depth', 3, 12),
        min_samples_split=trial.suggest_int('min_samples_split', 2, 10),
        min_samples_leaf=trial.suggest_int('min_samples_leaf', 1, 10),
        subsample=trial.suggest_float('subsample', 0.5, 1.0),
        max_features=trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        random_state=SEED
    )

    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_val_scaled)
    score = f1_score(y_val, y_pred, average='macro')
    return score

study_gb = optuna.create_study(direction='maximize')
study_gb.optimize(objective_gb, n_trials=50)

print("Best Gradient Boosting parameters:")
print(study_gb.best_params)
print("Best macro F1 Score:", study_gb.best_value)
# Out:
# [I 2025-05-27 17:01:17,999] A new study created in memory with name: no-name-644b7ecd-3d79-4264-aa66-ad03258d81d3
# [I 2025-05-27 17:12:09,483] Trial 0 finished with value: 0.8536314855237143 and parameters: {'n_estimators': 517, 'learning_rate': 0.09343488154668113, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 3, 'subsample': 0.7916547056907896, 'max_features': None}. Best is trial 0 with value: 0.8536314855237143.
# [I 2025-05-27 17:12:53,441] Trial 1 finished with value: 0.8364664183857763 and parameters: {'n_estimators': 781, 'learning_rate': 0.27294724490685723, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 9, 'subsample': 0.8249350268730133, 'max_features': 'log2'}. Best is trial 0 with value: 0.8536314855237143.
# [I 2025-05-27 17:22:56,538] Trial 2 finished with value: 0.8594324636225378 and parameters: {'n_estimators': 552, 'learning_rate': 0.19476972774554363, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.7743341022052974, 'max_features': None}. Best is trial 2 with value: 0.8594324636225378.
# [I 2025-05-27 17:23:49,978] Trial 3 finished with value: 0.8469339048943114 and parameters: {'n_estimators': 370, 'learning_rate': 0.16413404226565603, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.6475643159255368, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.8594324636225378.
'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.6839205454870193, 'max_features': None}. Best is trial 2 with value: 0.8594324636225378.
# [I 2025-05-27 18:42:47,178] Trial 15 finished with value: 0.8508785407190115 and parameters: {'n_estimators': 282, 'learning_rate': 0.1380683609012513, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 8, 'subsample': 0.7269871446310218, 'max_features': None}. Best is trial 2 with value: 0.8594324636225378.

# %%
# Train on full dataset
print("\nTraining on full dataset...")
# X_full_scaled = scaler.fit_transform(X)
X, y = smote.fit_resample(X, y)
gb_model_full = GradientBoostingClassifier(random_state=42, **gb_params)
gb_model_full.fit(X, y)
# Out:
# Training on full dataset...
# GradientBoostingClassifier(learning_rate=0.29728232981278574, max_depth=9,
#                            min_samples_leaf=5, min_samples_split=8,
#                            n_estimators=333, random_state=42,
#                            subsample=0.5822537141129174)

# %%
# Train on full dataset
print("\nTraining on full dataset...")
X_full_scaled = scaler.fit_transform(X)
train_data_full = lgb.Dataset(X_full_scaled, label=y)
final_model = lgb.train(lgb_params, train_data_full, num_boost_round=model.best_iteration)
# Out:
# Training on full dataset...

# %%
pip install autogluon --user
# Out:
# Requirement already satisfied: autogluon in c:\users\janen\appdata\roaming\python\python311\site-packages (1.3.1)
# Requirement already satisfied: autogluon.core==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.3.1->autogluon) (1.3.1)
# Requirement already satisfied: autogluon.features==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon) (1.3.1)
# Requirement already satisfied: autogluon.tabular==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (1.3.1)
# Requirement already satisfied: autogluon.multimodal==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon) (1.3.1)
# Requirement already satisfied: autogluon.timeseries==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.3.1->autogluon) (1.3.1)
# Requirement already satisfied: numpy<2.3.0,>=1.25.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2.1.3)
# Requirement already satisfied: scipy<1.16,>=1.5.4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.15.3)
# Requirement already satisfied: scikit-learn<1.7.0,>=1.4.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.6.1)
# Requirement already satisfied: networkx<4,>=3.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.4.2)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2.2.3)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (4.67.1)
# Requirement already satisfied: requests in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2.32.3)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.10.3)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.38.23)
# Requirement already satisfied: autogluon.common==1.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.3.1)
# Requirement already satisfied: psutil<7.1.0,>=5.7.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.common==1.3.1->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (7.0.0)
# Requirement already satisfied: ray<2.45,>=2.10.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (2.44.1)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.3.1->autogluon) (0.2.7)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.core[all]==1.3.1->autogluon) (20.0.0)
# Requirement already satisfied: Pillow<12,>=10.0.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.multimodal==1.3.1->autogluon) (11.2.1)
# Requirement already satisfied: torch<2.7,>=2.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (2.6.0)
# Requirement already satisfied: lightning<2.7,>=2.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (2.5.1.post0)
# Requirement already satisfied: transformers<4.50,>=4.38.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from transformers[sentencepiece]<4.50,>=4.38.0->autogluon.multimodal==1.3.1->autogluon) (4.49.0)
# Requirement already satisfied: accelerate<2.0,>=0.34.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.7.0)
# Requirement already satisfied: jsonschema<4.24,>=4.18 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.multimodal==1.3.1->autogluon) (4.23.0)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.4.3)
# Requirement already satisfied: timm<1.0.7,>=0.9.5 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.0.3)
# Requirement already satisfied: torchvision<0.22.0,>=0.16.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.21.0)
# Requirement already satisfied: scikit-image<0.26.0,>=0.19.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.25.2)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.8,>=1.2.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.7.1)
# Requirement already satisfied: omegaconf<2.4.0,>=2.1.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (2.3.0)
# Requirement already satisfied: pytorch-metric-learning<2.9,>=1.3.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (2.8.1)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.1.11)
# Requirement already satisfied: nltk<3.9,>=3.4.5 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.multimodal==1.3.1->autogluon) (3.1.6)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.multimodal==1.3.1->autogluon) (2.19.0)
# Requirement already satisfied: pytesseract<0.4,>=0.3.9 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (0.3.13)
# Requirement already satisfied: nvidia-ml-py3<8.0,>=7.352.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.3.1->autogluon) (1.17.0)
# Requirement already satisfied: catboost<1.3,>=1.2 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (1.2.8)
# Requirement already satisfied: einops<0.9,>=0.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (0.8.1)
# Requirement already satisfied: xgboost<3.1,>=2.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (2.1.4)
# Requirement already satisfied: fastai<2.9,>=2.3.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (2.8.2)
# Requirement already satisfied: huggingface-hub[torch] in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (0.31.4)
# Requirement already satisfied: lightgbm<4.7,>=4.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (4.6.0)
# Requirement already satisfied: spacy<3.9 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.3.1->autogluon) (3.8.7)
# Requirement already satisfied: joblib<2,>=1.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (1.5.0)
# Requirement already satisfied: pytorch-lightning in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.5.1.post0)
# Requirement already satisfied: gluonts<0.17,>=0.15.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.16.1)
# Requirement already satisfied: statsforecast<2.0.2,>=1.7.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.0.1)
# Requirement already satisfied: mlforecast<0.14,>0.13 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.13.6)
# Requirement already satisfied: utilsforecast<0.2.11,>=0.2.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.2.10)
# Requirement already satisfied: coreforecast<0.0.16,>=0.0.12 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.0.15)
# Requirement already satisfied: fugue>=0.9.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.9.1)
# Requirement already satisfied: orjson~=3.9 in c:\users\janen\appdata\roaming\python\python311\site-packages (from autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (3.10.18)
# Requirement already satisfied: packaging>=20.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from accelerate<2.0,>=0.34.0->autogluon.multimodal==1.3.1->autogluon) (24.2)
# Requirement already satisfied: pyyaml in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from accelerate<2.0,>=0.34.0->autogluon.multimodal==1.3.1->autogluon) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from accelerate<2.0,>=0.34.0->autogluon.multimodal==1.3.1->autogluon) (0.5.3)
# Requirement already satisfied: botocore<1.39.0,>=1.38.23 in c:\users\janen\appdata\roaming\python\python311\site-packages (from boto3<2,>=1.10->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.38.23)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from boto3<2,>=1.10->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from boto3<2,>=1.10->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from botocore<1.39.0,>=1.38.23->boto3<2,>=1.10->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from botocore<1.39.0,>=1.38.23->boto3<2,>=1.10->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2.4.0)
# Requirement already satisfied: graphviz in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.3.1->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.3.1->autogluon) (6.1.1)
# Requirement already satisfied: six in c:\users\janen\appdata\roaming\python\python311\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.3.1->autogluon) (1.17.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (2.14.4)
# Requirement already satisfied: dill in c:\users\janen\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\janen\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\janen\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (2025.5.0)
# Requirement already satisfied: pip in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (25.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (1.8.2)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (0.0.2)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (1.0.3)
# Requirement already satisfied: plum-dispatch in c:\users\janen\appdata\roaming\python\python311\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (2.5.7)
# Requirement already satisfied: cloudpickle in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (3.1.1)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.11.5)
# Requirement already satisfied: toolz~=0.10 in c:\users\janen\appdata\roaming\python\python311\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (4.12.2)
# Requirement already satisfied: future in c:\users\janen\appdata\roaming\python\python311\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.3.1->autogluon) (1.0.0)
# Requirement already satisfied: py4j in c:\users\janen\appdata\roaming\python\python311\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.3.1->autogluon) (0.10.9.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.3.1->autogluon) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from jsonschema<4.24,>=4.18->autogluon.multimodal==1.3.1->autogluon) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from jsonschema<4.24,>=4.18->autogluon.multimodal==1.3.1->autogluon) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from jsonschema<4.24,>=4.18->autogluon.multimodal==1.3.1->autogluon) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from jsonschema<4.24,>=4.18->autogluon.multimodal==1.3.1->autogluon) (0.25.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from lightning<2.7,>=2.2->autogluon.multimodal==1.3.1->autogluon) (0.14.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (3.12.2)
# Requirement already satisfied: setuptools in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning<2.7,>=2.2->autogluon.multimodal==1.3.1->autogluon) (72.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.2.3)
# Requirement already satisfied: numba in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.61.2)
# Requirement already satisfied: optuna in c:\users\janen\appdata\roaming\python\python311\site-packages (from mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (4.3.0)
# Requirement already satisfied: window-ops in c:\users\janen\appdata\roaming\python\python311\site-packages (from mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.3.1->autogluon) (5.2.0)
# Requirement already satisfied: click in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.3.1->autogluon) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.3.1->autogluon) (2024.11.6)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\janen\appdata\roaming\python\python311\site-packages (from omegaconf<2.4.0,>=2.1.1->autogluon.multimodal==1.3.1->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\users\janen\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\janen\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\janen\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (14.0.0)
# Requirement already satisfied: tabulate in c:\users\janen\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.4.1)
# Requirement already satisfied: filelock in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from ray<2.45,>=2.10.0->ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (3.18.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from ray<2.45,>=2.10.0->ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from ray<2.45,>=2.10.0->ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (5.29.4)
# Requirement already satisfied: aiosignal in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray<2.45,>=2.10.0->ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.3.2)
# Requirement already satisfied: frozenlist in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray<2.45,>=2.10.0->ray[default]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.6.0)
# Requirement already satisfied: aiohttp_cors in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.8.1)
# Requirement already satisfied: colorful in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.71.0)
# Requirement already satisfied: opencensus in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.11.4)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.22.0)
# Requirement already satisfied: smart_open in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (20.31.2)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\janen\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (2.6.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (2025.4.26)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from scikit-image<0.26.0,>=0.19.1->autogluon.multimodal==1.3.1->autogluon) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\janen\appdata\roaming\python\python311\site-packages (from scikit-image<0.26.0,>=0.19.1->autogluon.multimodal==1.3.1->autogluon) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from scikit-image<0.26.0,>=0.19.1->autogluon.multimodal==1.3.1->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from scikit-learn<1.7.0,>=1.4.0->autogluon.core==1.3.1->autogluon.core[all]==1.3.1->autogluon) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (0.16.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.3.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from statsforecast<2.0.2,>=1.7.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.14.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.3.1->autogluon) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.3.1->autogluon) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.3.1->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.3.1->autogluon) (3.1.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (0.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from torch<2.7,>=2.2->autogluon.multimodal==1.3.1->autogluon) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from sympy==1.13.1->torch<2.7,>=2.2->autogluon.multimodal==1.3.1->autogluon) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from transformers<4.50,>=4.38.0->transformers[sentencepiece]<4.50,>=4.38.0->autogluon.multimodal==1.3.1->autogluon) (0.21.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from transformers[sentencepiece]<4.50,>=4.38.0->autogluon.multimodal==1.3.1->autogluon) (0.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (0.21.1)
# Requirement already satisfied: wrapt in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from smart_open->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\janen\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.3.1->autogluon) (1.20.0)
# Requirement already satisfied: triad>=0.9.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fugue>=0.9.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fugue>=0.9.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.2.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.3.1->autogluon) (4.13.4)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.9->autogluon.tabular[all]==1.3.1->autogluon) (1.2.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from numba->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (0.44.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.1.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\janen\appdata\roaming\python\python311\site-packages (from statsmodels>=0.13.2->statsforecast<2.0.2,>=1.7.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (1.0.1)
# Requirement already satisfied: fs in c:\users\janen\appdata\roaming\python\python311\site-packages (from triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.4.16)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\janen\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (4.3.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.3.1->autogluon) (2.7)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from fs->triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (1.4.4)
# Requirement already satisfied: ordered-set in c:\users\janen\appdata\roaming\python\python311\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (2.24.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (2.40.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\janen\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\janen\appdata\roaming\python\python311\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.45,>=2.10.0; extra == "all"->autogluon.core[all]==1.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pycryptodome in c:\users\janen\appdata\roaming\python\python311\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (3.23.0)
# Requirement already satisfied: openxlab in c:\users\janen\appdata\roaming\python\python311\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (0.0.11)
# Requirement already satisfied: pywin32 in c:\users\janen\appdata\roaming\python\python311\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.3.1->autogluon) (309)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\janen\appdata\roaming\python\python311\site-packages (from optuna->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (1.16.1)
# Requirement already satisfied: colorlog in c:\users\janen\appdata\roaming\python\python311\site-packages (from optuna->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from optuna->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (2.0.41)
# Requirement already satisfied: Mako in c:\users\janen\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (1.3.10)
# Requirement already satisfied: greenlet>=1 in c:\users\janen\appdata\roaming\python\python311\site-packages (from sqlalchemy>=1.4.2->optuna->mlforecast<0.14,>0.13->autogluon.timeseries==1.3.1->autogluon.timeseries[all]==1.3.1->autogluon) (3.2.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from plotly->catboost<1.3,>=1.2->autogluon.tabular[all]==1.3.1->autogluon) (1.40.0)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\janen\appdata\roaming\python\python311\site-packages (from plum-dispatch->fastai<2.9,>=2.3.1->autogluon.tabular[all]==1.3.1->autogluon) (0.21.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\janen\appdata\roaming\python\python311\site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.3.1->autogluon) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from autogluon.tabular import TabularPredictor
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Combine train features and labels into a single DataFrame
train_df = X_train_scaled.copy()
train_df['label'] = y_train

# Define label column
label_column = 'label'

# Initialize and train AutoGluon predictor
predictor = TabularPredictor(label=label_column, eval_metric='f1_macro', verbosity=2).fit(
    train_df,
    time_limit=600,  # Optional: limit total training time (seconds)
    presets='best_quality'  # You can also try 'medium_quality_faster_train'
)

# Prepare validation set
val_df = X_val_scaled.copy()
val_df['label'] = y_val

# Predict
y_pred = predictor.predict(val_df.drop(columns=[label_column]))

# Evaluate
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\nValidation F1 Score (macro): {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_val, y_pred, target_names=['Cocoa', 'Palm', 'Rubber']))

# Confusion Matrix
cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Cocoa', 'Palm', 'Rubber'],
            yticklabels=['Cocoa', 'Palm', 'Rubber'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('AutoGluon Confusion Matrix')
plt.tight_layout()
plt.show()

# Best model summary
print("\nBest Model:", predictor.get_model_best())
print("\nLeaderboard:")
print(predictor.leaderboard(val_df, silent=True))
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20250527_123236"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.11
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          8
# Memory Avail:       4.77 GB / 15.86 GB (30.1%)
# Disk Space Avail:   337.00 GB / 476.13 GB (70.8%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-05-27 15:32:44,102	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\janen\Desktop\byte sized\AutogluonModels\ag-20250527_123236\ds_sub_fit\sub_fit_ho"
# (_dystack pid=3480) Running DyStack sub-fit ...
# (_dystack pid=3480) Beginning AutoGluon training ... Time limit = 139s
# (_dystack pid=3480) AutoGluon will save models to "c:\Users\janen\Desktop\byte sized\AutogluonModels\ag-20250527_123236\ds_sub_fit\sub_fit_ho"
# (_dystack pid=3480) Train Data Rows:    6589
# (_dystack pid=3480) Train Data Columns: 108
# (_dystack pid=3480) Label Column:       label
# (_dystack pid=3480) Problem Type:       multiclass
# (_dystack pid=3480) Preprocessing data ...
# (_dystack pid=3480) Train Data Class Count: 3
# (_dystack pid=3480) Using Feature Generators to preprocess the data ...
# (_dystack pid=3480) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=3480) 	Available Memory:                    4308.08 MB
# (_dystack pid=3480) 	Train Data (Original)  Memory Usage: 5.43 MB (0.1% of available memory)
# (_dystack pid=3480) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=3480) 	Stage 1 Generators:
# (_dystack pid=3480) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=3480) 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=3480) 	Stage 2 Generators:
# (_dystack pid=3480) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=3480) 	Stage 3 Generators:
# (_dystack pid=3480) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=3480) 	Stage 4 Generators:
# (_dystack pid=3480) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=3480) 	Stage 5 Generators:
# (_dystack pid=3480) 		Fitting DropDuplicatesFeatureGenerator...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 15
#      12 label_column = 'label'
#      14 # Initialize and train AutoGluon predictor
# ---> 15 predictor = TabularPredictor(label=label_column, eval_metric='f1_macro', verbosity=2).fit(
#      16     train_df,
#      17     time_limit=600,  # Optional: limit total training time (seconds)
#      18     presets='best_quality'  # You can also try 'medium_quality_faster_train'
#      19 )
#      21 # Prepare validation set
#      22 val_df = X_val_scaled.copy()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogluon\core\utils\decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogluon\tabular\predictor\predictor.py:1282, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, fit_strategy, memory_limit, callbacks, **kwargs)
#    1276 if dynamic_stacking:
#    1277     logger.log(
#    1278         20,
#    1279         f"DyStack is enabled (dynamic_stacking={dynamic_stacking}). "
#    1280         "AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.",
#    1281     )
# -> 1282     num_stack_levels, time_limit = self._dynamic_stacking(**ds_args, ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1283     logger.info(
#    1284         f"Starting main fit with num_stack_levels={num_stack_levels}.\n"
#    1285         f"\tFor future fit calls on this dataset, you can skip DyStack to save time: "
#    1286         f"`predictor.fit(..., dynamic_stacking=False, num_stack_levels={num_stack_levels})`"
#    1287     )
#    1289     if (time_limit is not None) and (time_limit <= 0):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogluon\tabular\predictor\predictor.py:1382, in TabularPredictor._dynamic_stacking(self, ag_fit_kwargs, ag_post_fit_kwargs, validation_procedure, detection_time_frac, holdout_frac, n_folds, n_repeats, memory_safe_fits, clean_up_fits, enable_ray_logging, enable_callbacks, holdout_data)
#    1379         _, holdout_data, _, _ = self._validate_fit_data(train_data=X, tuning_data=holdout_data)
#    1380         ds_fit_kwargs["ds_fit_context"] = os.path.join(ds_fit_context, "sub_fit_custom_ho")
# -> 1382     stacked_overfitting = self._sub_fit_memory_save_wrapper(
#    1383         train_data=X,
#    1384         time_limit=time_limit,
#    1385         time_start=time_start,
#    1386         ds_fit_kwargs=ds_fit_kwargs,
#    1387         ag_fit_kwargs=inner_ag_fit_kwargs,
#    1388         ag_post_fit_kwargs=inner_ag_post_fit_kwargs,
#    1389         holdout_data=holdout_data,
#    1390     )
#    1391 else:
#    1392     # Holdout is false, use (repeated) cross-validation
#    1393     is_stratified = self.problem_type in [BINARY, MULTICLASS]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogluon\tabular\predictor\predictor.py:1574, in TabularPredictor._sub_fit_memory_save_wrapper(self, train_data, time_limit, time_start, ds_fit_kwargs, ag_fit_kwargs, ag_post_fit_kwargs, holdout_data)
#    1560 # FIXME: For some reason ray does not treat `num_cpus` and `num_gpus` the same.
#    1561 #  For `num_gpus`, the process will reserve the capacity and is unable to share it to child ray processes, causing a deadlock.
#    1562 #  For `num_cpus`, the value is completely ignored by children, and they can even use more num_cpus than the parent.
#    1563 #  Because of this, num_gpus is set to 0 here to avoid a deadlock, but num_cpus does not need to be changed.
#    1564 #  For more info, refer to Ray documentation: https://docs.ray.io/en/latest/ray-core/tasks/nested-tasks.html#yielding-resources-while-blocked
#    1565 ref = sub_fit_caller.options(num_cpus=num_cpus, num_gpus=0).remote(
#    1566     predictor=predictor_ref,
#    1567     train_data=train_data_ref,
#    (...)   1572     holdout_data=holdout_data_ref,
#    1573 )
# -> 1574 finished, unfinished = _ds_ray.wait([ref], num_returns=1)
#    1575 stacked_overfitting, ho_leaderboard, exception = _ds_ray.get(finished[0])
#    1577 # TODO: This is present to ensure worker logs are properly logged and don't get skipped / printed out of order.
#    1578 #  Ideally find a faster way to do this that doesn't introduce a 100 ms overhead.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ray\_private\auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ray\_private\worker.py:3013, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3011 timeout = timeout if timeout is not None else 10**6
#    3012 timeout_milliseconds = int(timeout * 1000)
# -> 3013 ready_ids, remaining_ids = worker.core_worker.wait(
#    3014     ray_waitables,
#    3015     num_returns,
#    3016     timeout_milliseconds,
#    3017     fetch_local,
#    3018 )
#    3019 return ready_ids, remaining_ids
#
# File python\\ray\\_raylet.pyx:3529, in ray._raylet.CoreWorker.wait()
#
# File python\\ray\\includes/common.pxi:83, in ray._raylet.check_status()
#
# KeyboardInterrupt:
# (_dystack pid=3480) 	Unused Original Features (Count: 5): ['B11_B8', 'min_nir', 'min_rededge', 'max_rededge', 'avg_rededge']
# (_dystack pid=3480) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=3480) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=3480) 		These features do not need to be present at inference time.
# (_dystack pid=3480) 		('float', []) : 5 | ['B11_B8', 'min_nir', 'min_rededge', 'max_rededge', 'avg_rededge']
# (_dystack pid=3480) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=3480) 		('float', []) : 99 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=3480) 		('int', [])   :  4 | ['month_num', 'season', 'growth_phase', 'is_growing_season']
# (_dystack pid=3480) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=3480) 		('float', [])     : 99 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=3480) 		('int', [])       :  3 | ['month_num', 'season', 'growth_phase']
# (_dystack pid=3480) 		('int', ['bool']) :  1 | ['is_growing_season']
# (_dystack pid=3480) 	2.3s = Fit runtime
# (_dystack pid=3480) 	103 features in original data used to generate 103 features in processed data.
# (_dystack pid=3480) 	Train Data (Processed) Memory Usage: 5.13 MB (0.1% of available memory)
# (_dystack pid=3480) Data preprocessing and feature engineering runtime = 2.31s ...
# (_dystack pid=3480) AutoGluon will gauge predictive performance using evaluation metric: 'f1_macro'
# (_dystack pid=3480) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=3480) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=3480) User-specified model hyperparameters to be fit:
# (_dystack pid=3480) {
# (_dystack pid=3480) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=3480) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=3480) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=3480) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=3480) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=3480) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=3480) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=3480) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=3480) }
# (_dystack pid=3480) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=3480) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=3480) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 90.97s of the 136.48s of remaining time.
# (_dystack pid=3480) 	0.5865	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	0.12s	 = Training   runtime
# (_dystack pid=3480) 	0.54s	 = Validation runtime
# (_dystack pid=3480) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 72.33s of the 117.84s of remaining time.
# (_dystack pid=3480) 	0.6398	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	0.05s	 = Training   runtime
# (_dystack pid=3480) 	0.51s	 = Validation runtime
# (_dystack pid=3480) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 71.65s of the 117.15s of remaining time.
# (_dystack pid=3480) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.36%)
# (_dystack pid=3480) 	0.8834	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	32.4s	 = Training   runtime
# (_dystack pid=3480) 	0.4s	 = Validation runtime
# (_dystack pid=3480) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 27.84s of the 73.35s of remaining time.
# (_dystack pid=3480) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.43%)
# (_ray_fit pid=16088) 	Ran out of time, early stopping on iteration 293. Best iteration is:
# (_ray_fit pid=16088) 	[281]	valid_set's multi_logloss: 0.31477	valid_set's f1_macro: 0.865158
# (_dystack pid=3480) 	0.8693	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	24.21s	 = Training   runtime
# (_dystack pid=3480) 	2.11s	 = Validation runtime
# (_dystack pid=3480) Fitting model: WeightedEnsemble_L2 ... Training model for up to 136.49s of the 37.42s of remaining time.
# (_dystack pid=3480) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.444, 'LightGBMXT_BAG_L1': 0.333, 'KNeighborsDist_BAG_L1': 0.222}
# (_dystack pid=3480) 	0.8911	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	0.97s	 = Training   runtime
# (_dystack pid=3480) 	0.01s	 = Validation runtime
# (_dystack pid=3480) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=3480) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 36.38s of the 36.31s of remaining time.
# (_dystack pid=3480) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.31%)
# (_ray_fit pid=10932) No improvement since epoch 7: early stopping
# (_ray_fit pid=19204) No improvement since epoch 5: early stopping
# (_dystack pid=3480) 	0.8943	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	39.45s	 = Training   runtime
# (_dystack pid=3480) 	0.46s	 = Validation runtime
# (_dystack pid=3480) Fitting model: WeightedEnsemble_L3 ... Training model for up to 136.49s of the -12.43s of remaining time.
# (_dystack pid=3480) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.72, 'LightGBMXT_BAG_L1': 0.12, 'KNeighborsDist_BAG_L1': 0.08, 'NeuralNetFastAI_BAG_L1': 0.08}
# (_dystack pid=3480) 	0.8956	 = Validation score   (f1_macro)
# (_dystack pid=3480) 	1.13s	 = Training   runtime
# (_dystack pid=3480) 	0.01s	 = Validation runtime
# (_dystack pid=3480) AutoGluon training complete, total runtime = 152.42s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 264.8 rows/s (824 batch size)
# (_dystack pid=3480) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\janen\Desktop\byte sized\AutogluonModels\ag-20250527_123236\ds_sub_fit\sub_fit_ho")
# (_dystack pid=3480) Deleting DyStack predictor artifacts (clean_up_fits=True) ...

# %%
# !pip install flaml
# Out:
# Requirement already satisfied: flaml in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (2.3.4)
# Requirement already satisfied: NumPy>=1.17 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from flaml) (2.1.3)

# %%
from flaml.automl import AutoML
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Initialize AutoML
automl = AutoML()

# Set settings
automl_settings = {
    "time_budget": 600,  # seconds
    "metric": 'macro_f1',
    "task": 'classification',
    "log_file_name": "flaml_classification.log",
    "seed": 42
}

# Train AutoML
automl.fit(X_train=X_train_scaled, y_train=y_train, **automl_settings)

# Predict
y_pred = automl.predict(X_val_scaled)

# Evaluate
f1 = f1_score(y_val, y_pred, average='macro')
print(f"\n[FLAML] Validation F1 Score (macro): {f1:.4f}")
print("\n[FLAML] Classification Report:")
print(classification_report(y_val, y_pred, target_names=['Cocoa', 'Palm', 'Rubber']))

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_val, y_pred), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Cocoa', 'Palm', 'Rubber'],
            yticklabels=['Cocoa', 'Palm', 'Rubber'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('FLAML Confusion Matrix')
plt.tight_layout()
plt.show()

# Best model and config
print("\nBest FLAML model:", automl.model.estimator)
print("Best FLAML hyperparameters:", automl.best_config)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 from flaml.automl import AutoML
#       2 from sklearn.metrics import f1_score, classification_report, confusion_matrix
#       3 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'AutoML' from 'flaml.automl' (c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\flaml\automl\__init__.py)

# %%
# !pip install h2o  --user
# Out:
# Collecting h2o
#   Using cached h2o-3.46.0.7-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from h2o) (2.32.3)
# Requirement already satisfied: tabulate in c:\users\janen\appdata\roaming\python\python311\site-packages (from h2o) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->h2o) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->h2o) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->h2o) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janen\anaconda3\envs\ml_env\lib\site-packages (from requests->h2o) (2025.4.26)
# Downloading h2o-3.46.0.7-py2.py3-none-any.whl (265.9 MB)
#    ---------------------------------------- 0.0/265.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/265.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/265.9 MB 1.5 MB/s eta 0:02:55
#    ---------------------------------------- 0.8/265.9 MB 1.3 MB/s eta 0:03:18
#    ---------------------------------------- 0.8/265.9 MB 1.3 MB/s eta 0:03:18
#    ---------------------------------------- 1.3/265.9 MB 1.3 MB/s eta 0:03:22
#    ---------------------------------------- 1.6/265.9 MB 1.3 MB/s eta 0:03:19
#    ---------------------------------------- 1.8/265.9 MB 1.3 MB/s eta 0:03:20
#    ---------------------------------------- 2.1/265.9 MB 1.4 MB/s eta 0:03:07
#    ---------------------------------------- 2.4/265.9 MB 1.4 MB/s eta 0:03:11
#    ---------------------------------------- 2.6/265.9 MB 1.4 MB/s eta 0:03:12
#    ---------------------------------------- 2.9/265.9 MB 1.4 MB/s eta 0:03:15
#    ---------------------------------------- 3.1/265.9 MB 1.3 MB/s eta 0:03:15
#     --------------------------------------- 3.7/265.9 MB 1.4 MB/s eta 0:03:14
#     --------------------------------------- 3.9/265.9 MB 1.3 MB/s eta 0:03:15
#     --------------------------------------- 4.2/265.9 MB 1.4 MB/s eta 0:03:14
#     --------------------------------------- 4.5/265.9 MB 1.4 MB/s eta 0:03:12
#     --------------------------------------- 4.7/265.9 MB 1.4 MB/s eta 0:03:12
#     --------------------------------------- 5.0/265.9 MB 1.4 MB/s eta 0:03:11
#     --------------------------------------- 5.2/265.9 MB 1.4 MB/s eta 0:03:10
#     --------------------------------------- 5.5/265.9 MB 1.4 MB/s eta 0:03:10
#     --------------------------------------- 5.8/265.9 MB 1.4 MB/s eta 0:03:11
#     --------------------------------------- 6.0/265.9 MB 1.3 MB/s eta 0:03:13
#     --------------------------------------- 6.3/265.9 MB 1.3 MB/s eta 0:03:14
#     --------------------------------------- 6.6/265.9 MB 1.3 MB/s eta 0:03:15
#    - -------------------------------------- 6.8/265.9 MB 1.3 MB/s eta 0:03:15
#    -------------------------------------  264.8/265.9 MB 856.3 kB/s eta 0:00:02
#    -------------------------------------  265.0/265.9 MB 848.5 kB/s eta 0:00:02
#    -------------------------------------  265.3/265.9 MB 842.4 kB/s eta 0:00:01
#    -------------------------------------  265.3/265.9 MB 842.4 kB/s eta 0:00:01
#    -------------------------------------  265.6/265.9 MB 833.6 kB/s eta 0:00:01
#    -------------------------------------  265.6/265.9 MB 833.6 kB/s eta 0:00:01
#    -------------------------------------  265.8/265.9 MB 825.7 kB/s eta 0:00:01
#    -------------------------------------  265.8/265.9 MB 825.7 kB/s eta 0:00:01
#    -------------------------------------  265.8/265.9 MB 825.7 kB/s eta 0:00:01
#    -------------------------------------- 265.9/265.9 MB 792.6 kB/s eta 0:00:00
# Installing collected packages: h2o
# Successfully installed h2o-3.46.0.7

# %%
import h2o
from h2o.automl import H2OAutoML
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Start H2O cluster
h2o.init()

# Combine train and val sets
train_df = X_train_scaled.copy()
train_df['label'] = y_train
val_df = X_val_scaled.copy()
val_df['label'] = y_val

# Convert to H2OFrame
h2o_train = h2o.H2OFrame(train_df)
h2o_val = h2o.H2OFrame(val_df)

# Set column types
h2o_train['label'] = h2o_train['label'].asfactor()
h2o_val['label'] = h2o_val['label'].asfactor()

# Run AutoML
aml = H2OAutoML(max_models=20, seed=42, sort_metric='mean_per_class_error')  # or sort_metric='mean_per_class_f1'
aml.train(y='label', training_frame=h2o_train)

# Predict
preds = aml.leader.predict(h2o_val).as_data_frame()['predict'].astype(int)

# Evaluate
f1 = f1_score(y_val, preds, average='macro')
print(f"\n[H2O] Validation F1 Score (macro): {f1:.4f}")
print("\n[H2O] Classification Report:")
print(classification_report(y_val, preds, target_names=['Cocoa', 'Palm', 'Rubber']))

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_val, preds), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Cocoa', 'Palm', 'Rubber'],
            yticklabels=['Cocoa', 'Palm', 'Rubber'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('H2O AutoML Confusion Matrix')
plt.tight_layout()
plt.show()

# Best model
print("\nBest H2O Model:", aml.leader.model_id)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\h2o.py:270, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, verbose, **kwargs)
#     269 try:
# --> 270     h2oconn = H2OConnection.open(url=url, ip=ip, port=port, name=name, https=https,
#     271                                  verify_ssl_certificates=verify_ssl_certificates, cacert=cacert,
#     272                                  auth=auth, proxy=proxy, cookies=cookies, verbose=verbose,
#     273                                  msgs=("Checking whether there is an H2O instance running at {url}",
#     274                                        "connected.", "not found."),
#     275                                  strict_version_check=svc)
#     276 except H2OConnectionError:
#     277     # Backward compatibility: in init() port parameter really meant "baseport" when starting a local server...
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\backend\connection.py:406, in H2OConnection.open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, msgs, strict_version_check)
#     405 conn._timeout = 3.0
# --> 406 conn._cluster = conn._test_connection(retries, messages=msgs)
#     407 # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#     408 # setting for now, for no good reason other than to ignore all those bugs :(
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\backend\connection.py:713, in H2OConnection._test_connection(self, max_retries, messages)
#     712 else:
# --> 713     raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
#     714                              % (self._base_url, max_retries, "\n".join(errors)))
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [10:28.19] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002AEACA63950>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# [10:32.45] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002AEACABD950>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# [10:36.72] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002AEACABE490>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# [10:40.97] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002AEACA5D690>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# [10:45.25] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002AEACA75610>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# H2OStartupError                           Traceback (most recent call last)
# Cell In[131], line 9
#       6 import pandas as pd
#       8 # Start H2O cluster
# ----> 9 h2o.init()
#      11 # Combine train and val sets
#      12 train_df = X_train_scaled.copy()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\h2o.py:287, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, verbose, **kwargs)
#     283     if https:
#     284         raise H2OConnectionError('Starting local server is not available with https enabled. You may start local'
#     285                                  ' instance of H2O with https manually '
#     286                                  '(https://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#new-user-quick-start).')
# --> 287     hs = H2OLocalServer.start(nthreads=nthreads, enable_assertions=enable_assertions, max_mem_size=mmax,
#     288                               min_mem_size=mmin, ice_root=ice_root, log_dir=log_dir, log_level=log_level,
#     289                               max_log_file_size=max_log_file_size, port=port, name=name,
#     290                               extra_classpath=extra_classpath, jvm_custom_args=jvm_custom_args,
#     291                               bind_to_localhost=bind_to_localhost,verbose=verbose)
#     292     h2oconn = H2OConnection.open(server=hs, https=https, verify_ssl_certificates=verify_ssl_certificates,
#     293                                  cacert=cacert, auth=auth, proxy=proxy, cookies=cookies, verbose=verbose,
#     294                                  strict_version_check=svc)
#     295 h2oconn.cluster.timezone = "UTC"
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\backend\server.py:139, in H2OLocalServer.start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, max_log_file_size, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     136     hs._tempdir = hs._ice_root
#     138 if verbose: print("Attempting to start a local H2O server...")
# --> 139 hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     140                   mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
#     141                   bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level, max_log_file_size=max_log_file_size)
#     142 if verbose: print("  Server is running at %s://%s:%d" % (hs.scheme, hs.ip, hs.port))
#     143 atexit.register(lambda: hs.shutdown())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\backend\server.py:271, in H2OLocalServer._launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level, max_log_file_size)
#     268 self._ip = "127.0.0.1"
#     270 # Find Java and check version. (Note that subprocess.check_output returns the output as a bytes object)
# --> 271 java = self._find_java()
#     272 self._check_java(java, self._verbose)
#     274 if self._verbose:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\h2o\backend\server.py:453, in H2OLocalServer._find_java()
#     450                 return os.path.join(dirpath, java)
#     452 # not found...
# --> 453 raise H2OStartupError("Cannot find Java. Please install the latest JRE from\n"
#     454                       "http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements")
#
# H2OStartupError: Cannot find Java. Please install the latest JRE from
# http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# # Lets do the CV
# from sklearn.model_selection import StratifiedKFold

# n_splits = 5
# skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# # Store metrics
# f1_scores = []
# thresholds_per_class = []
# all_val_preds = []
# all_val_true = []

# for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
#     print(f"\n--- Fold {fold + 1} ---")

#     X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
#     X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

#     sample_weights = np.array([class_weights_dict[label] for label in y_train])

#     dtrain = lgb.Dataset(X_train, label=y_train, weight=sample_weights)
#     dval = lgb.Dataset(X_val, label=y_val, reference=dtrain)

#     model = lgb.train(
#         params=lgb_params,
#         train_set=dtrain,
#         num_boost_round=1000,
#         valid_sets=[dtrain, dval],
#         valid_names=['train', 'valid'],
#         callbacks=[lgb.early_stopping(stopping_rounds=100)]
#     )

#     val_probs = model.predict(X_val, num_iteration=model.best_iteration)

#     best_thresholds = [0.5] * 3
#     best_f1 = 0

#     # Optimize threshold per class
#     for t0 in np.arange(0.1, 0.9, 0.05):
#         for t1 in np.arange(0.1, 0.9, 0.05):
#             for t2 in np.arange(0.1, 0.9, 0.05):
#                 thresholds = [t0, t1, t2]
#                 val_preds = []
#                 for probs in val_probs:
#                     pred = np.argmax([probs[0] > t0, probs[1] > t1, probs[2] > t2])
#                     val_preds.append(pred)

#                 f1 = f1_score(y_val, val_preds, average='macro')
#                 if f1 > best_f1:
#                     best_f1 = f1
#                     best_thresholds = thresholds

#     print(f"Fold {fold + 1} Best Thresholds: {best_thresholds}")
#     print(f"Fold {fold + 1} F1 Score: {best_f1:.4f}")

#     # Final predictions with best thresholds
#     final_preds = []
#     for probs in val_probs:
#         pred = np.argmax([probs[0] > best_thresholds[0], probs[1] > best_thresholds[1], probs[2] > best_thresholds[2]])
#         final_preds.append(pred)

#     thresholds_per_class.append(best_thresholds)
#     f1_scores.append(best_f1)
#     all_val_preds.extend(final_preds)
#     all_val_true.extend(y_val)

# # Final cross-validated results
# print("\n=== Cross-Validation Results ===")
# print(f"Average F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
# print(f"Average Best Thresholds: {np.mean(thresholds_per_class, axis=0)}")

# print("\nClassification Report:")
# print(classification_report(all_val_true, all_val_preds))

# print("Confusion Matrix:")
# cm = confusion_matrix(all_val_true, all_val_preds)
# print(cm)

# # Plot confusion matrix
# plt.figure(figsize=(8,6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel("Predicted")
# plt.ylabel("Actual")
# plt.title("Confusion Matrix")
# plt.show()

# %% [markdown]
# ### Submission

# %%
X_test_scaled = test_features_df[feature_cols]

# %%
test_preds = gb_model_full.predict_proba(X_test_scaled)  # Use predict_proba instead of predict
test_df['prediction'] = np.argmax(test_preds, axis=1)
test_df['prediction_label'] = test_df['prediction'].map({0: 'Cocoa', 1: 'Palm', 2: 'Rubber'})

# %%
test_df.head()
# Out:
#               ID month         B1         B2         B3         B4         B5  \
# 0  ID_790093_Jan   Jan  2621.2246  2309.7244  2110.1357  1875.1238  1988.7589
# 1  ID_079024_Jan   Jan  2568.5417  2267.9055  2090.8132  1856.0846  2008.3160
# 2  ID_931033_Jan   Jan  2632.4868  2360.5725  2244.7156  2045.7086  2303.4744
# 3  ID_731818_Jan   Jan  3065.4858  2848.5762  2737.4430  2650.5790  2782.1729
# 4  ID_691532_Jan   Jan  2507.0132  2213.9631  2045.4926  1812.7167  2008.9689
#
#           B6         B7         B8  ...  avg_veg_index  avg_stress_index  \
# 0  2700.0068  3054.5881  2864.1042  ...      -0.024423          0.272185
# 1  2795.9731  3165.8930  3008.3333  ...      -0.058479          0.280309
# 2  3405.9968  3931.5598  3743.2495  ...      -0.383527          0.292192
# 3  3667.0303  4166.7627  3923.6260  ...      -0.352389          0.310000
# 4  2857.1953  3268.1907  3099.5610  ...      -0.091122          0.281219
#
#    color_ratio_avg  NDVI_squared EVI_squared NDWI_squared  NDVI_EVI_product  \
# 0         0.445633      0.043547    0.594339     0.022975         -0.160878
# 1         0.496933      0.056109    1.012029     0.032377         -0.238293
# 2         0.591070      0.085988    6.337416     0.062629         -0.738203
# 3         0.537589      0.037498    4.292015     0.031711         -0.401173
# 4         0.531204      0.068626    1.498742     0.041972         -0.320706
#
#    SAVI_NDWI_product  prediction  prediction_label
# 0          -0.047441           1              Palm
# 1          -0.063926           2            Rubber
# 2          -0.110068           2            Rubber
# 3          -0.051721           1              Palm
# 4          -0.080495           2            Rubber
#
# [5 rows x 114 columns]

# %%
test_df = test_features_df.copy()
test_preds = gb_model_full.predict(X_test_scaled)
test_df['prediction'] = np.argmax(test_preds, axis=1)
test_df['prediction_label'] = test_df['prediction'].map({0: 'Cocoa', 1: 'Palm', 2: 'Rubber'})
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[113], line 3
#       1 test_df = test_features_df.copy()
#       2 test_preds = gb_model_full.predict(X_test_scaled)
# ----> 3 test_df['prediction'] = np.argmax(test_preds, axis=1)
#       4 test_df['prediction_label'] = test_df['prediction'].map({0: 'Cocoa', 1: 'Palm', 2: 'Rubber'})
#       5 test_df.head()
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\numpy\_core\fromnumeric.py:1342, in argmax(a, axis, out, keepdims)
#    1253 """
#    1254 Returns the indices of the maximum values along an axis.
#    1255
#    (...)   1339 (2, 1, 4)
#    1340 """
#    1341 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1342 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\janen\anaconda3\envs\ml_env\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
# Get prediction probabilities
test_df['prob_cocoa'] = test_preds[:, 0]
test_df['prob_palm'] = test_preds[:, 1]
test_df['prob_rubber'] = test_preds[:, 2]

# Aggregate predictions by base_id using most frequent prediction
test_df['base_id'] = test_df['ID'].str.split('_').str[1]

agg_most_frequent = test_df.groupby('base_id')['prediction_label'].agg(
    lambda x: x.value_counts().index[0]
).reset_index()

# %%
# Create submission file
submission = pd.DataFrame({
    'ID': 'ID_' + agg_most_frequent['base_id'],
    'Target': agg_most_frequent['prediction_label']
})

print(submission['Target'].value_counts())
print()
print(f"Final submission shape: {submission.shape}")
submission.to_csv('byte_sized_submission.csv', index=False)
# Out:
# Target
# Rubber    123
# Palm      106
# Cocoa      53
# Name: count, dtype: int64
#
# Final submission shape: (282, 2)
